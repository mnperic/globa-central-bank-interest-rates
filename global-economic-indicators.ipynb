# %%
# Import dependencies and setup

import pandas as pd
import matplotlib.pyplot as plt
import matplotlib as matplotlib
import matplotlib.dates as matplotlibdates
from matplotlib.dates import date2num

# %%
## Read .csv files and store as DataFrames

# %%
# banking sector leverage
# business confidence index (BCI)
# composite leading indicator (CLI)
# consumer confidence index (CCI)
# exchange rates
# financial corporate debt to equity ratio
# general government deficit
# gross domestic product (GDP)
# quarterly gross domestic product (QGDP)
# household debt
# household disposable income
# inflation (CPI)
# long term interest rates
# part-time employment rate
# short term interest rates
# unemployment rate
# youth_unemployment rate

banking_sector_leverage_path = "Resources/banking_sector_leverage.csv"
bsl_df = pd.read_csv(banking_sector_leverage_path)

business_confidence_index_path = "Resources/business_confidence_index_bci.csv"
bci_df = pd.read_csv(business_confidence_index_path)

composite_leading_indicator_path = "Resources/composite_leading_indicator_cli.csv"
cli_df = pd.read_csv(composite_leading_indicator_path)

consumer_confidence_index_path = "Resources/consumer_confidence_index_cci.csv"
cci_df = pd.read_csv(consumer_confidence_index_path)

exchange_rates_path = "Resources/exchange_rates.csv"
exchange_rates_df = pd.read_csv(exchange_rates_path)

financial_corporate_debt_to_equity_path = "Resources/financial_corporate_debt_to_equity.csv"
fcdter_df = pd.read_csv(financial_corporate_debt_to_equity_path)

general_government_deficit_path = "Resources/general_government_deficit.csv"
ggd_df = pd.read_csv(general_government_deficit_path)

gdp_path = "Resources/gross_domestic_product_gdp.csv"
gdp_df = pd.read_csv(gdp_path)

quarterly_gdp_path = "Resources/quarterly_gross_domestic_product_gdp.csv"
qgdp_df = pd.read_csv(quarterly_gdp_path)

household_debt_path = "Resources/household_debt.csv"
household_debt_df = pd.read_csv(household_debt_path)

household_disposable_income_path = "Resources/household_disposable_income.csv"
hdi_df = pd.read_csv(household_disposable_income_path)

inflation_cpi_path = "Resources/inflation.csv"
cpi_df = pd.read_csv(inflation_cpi_path)

long_term_interest_rates_path = "Resources/long_term_interest_rates.csv"
ltir_df = pd.read_csv(long_term_interest_rates_path)

part_time_employment_rate_path = "Resources/part-time_employment_rate.csv"
pter_df = pd.read_csv(part_time_employment_rate_path)

short_term_interest_rates_path = "Resources/short_term_interest_rates.csv"
stir_df = pd.read_csv(short_term_interest_rates_path)

unemployment_rate_path = "Resources/unemployment_rate.csv"
unemployment_df = pd.read_csv(unemployment_rate_path)

youth_unemployment_rate_path = "Resources/youth_unemployment_rate.csv"
youth_unemployment_df = pd.read_csv(youth_unemployment_rate_path)

# %%
# # Convert all 'TIME' columns datatype to datetime

bsl_df['TIME'] = pd.to_datetime(bsl_df['TIME'], format='%Y')
bci_df['TIME'] = pd.to_datetime(bci_df['TIME'], format='%Y-%m')
cli_df['TIME'] = pd.to_datetime(cli_df['TIME'], format='%Y-%m')
cci_df['TIME'] = pd.to_datetime(cci_df['TIME'], format='%Y-%m')
exchange_rates_df['TIME'] = pd.to_datetime(exchange_rates_df['TIME'], format='%Y')
fcdter_df['TIME'] = pd.to_datetime(fcdter_df['TIME'], format='%Y')
ggd_df['TIME'] = pd.to_datetime(ggd_df['TIME'], format='%Y')
gdp_df['TIME'] = pd.to_datetime(gdp_df['TIME'], format='%Y')
qgdp_df['TIME'] = pd.to_datetime(qgdp_df['TIME'])
household_debt_df['TIME'] = pd.to_datetime(household_debt_df['TIME'], format='%Y')
hdi_df['TIME'] = pd.to_datetime(hdi_df['TIME'], format='%Y')
cpi_df['TIME'] = pd.to_datetime(cpi_df['TIME'], format='%Y')
ltir_df['TIME'] = pd.to_datetime(ltir_df['TIME'], format='%Y')
pter_df['TIME'] = pd.to_datetime(pter_df['TIME'], format='%Y')
stir_df['TIME'] = pd.to_datetime(stir_df['TIME'], format='%Y')
unemployment_df['TIME'] = pd.to_datetime(unemployment_df['TIME'], format='%Y')
youth_unemployment_df['TIME'] = pd.to_datetime(youth_unemployment_df['TIME'], format='%Y')

# %%
## Banking Sector Leverage

# %%
# Create new DataFrames based on locations (countries)

bsl_df['LOCATION'].unique()
    
aus_bsl_df = bsl_df[bsl_df.LOCATION == 'AUS'] #Australia
can_bsl_df = bsl_df[bsl_df.LOCATION == 'CAN'] #Canada
deu_bsl_df = bsl_df[bsl_df.LOCATION == 'DEU'] #Germany
fra_bsl_df = bsl_df[bsl_df.LOCATION == 'FRA'] #France
gbr_bsl_df = bsl_df[bsl_df.LOCATION == 'GBR'] #Great Britain
ita_bsl_df = bsl_df[bsl_df.LOCATION == 'ITA'] #Italy
jpn_bsl_df = bsl_df[bsl_df.LOCATION == 'JPN'] #Japan
usa_bsl_df = bsl_df[bsl_df.LOCATION == 'USA'] #USA

bsl_df
# Out:
#     LOCATION       TIME     VALUE
# 0        AUS 1995-01-01  6.080544
# 1        AUS 1996-01-01  5.527361
# 2        AUS 1997-01-01  4.681720
# 3        AUS 1998-01-01  4.525223
# 4        AUS 1999-01-01  4.776768
# ..       ...        ...       ...
# 203      USA 2016-01-01  7.027997
# 204      USA 2017-01-01  6.737813
# 205      USA 2018-01-01  7.132571
# 206      USA 2019-01-01  6.624769
# 207      USA 2020-01-01  8.625169
#
# [208 rows x 3 columns]

# %%
# Plotting – BSL (Australia)

# Font families
font_1 = {'family':'helvetica','color':'black','size':16}
font_2 = {'family':'helvetica','color':'black','size':12}

# Plot
plt.figure(figsize=(15,5))
plt.plot(aus_bsl_df['TIME'], aus_bsl_df['VALUE'], color='blue', linewidth=3)

# Labels
plt.title("Banking Sector Leverage (Equity Multiplier Ratio) – Australia, yearly average (1995–2020)", fontdict = font_1)
plt.xlabel("Year", fontdict = font_2)
plt.ylabel("% of net value added", fontdict = font_2)

# Highlights
plt.axvspan(date2num(datetime(2007,1,1)), date2num(datetime(2009,1,1)), 
           label="2008 Global Financial Crisis", color="red", alpha=0.1)

plt.axvspan(date2num(datetime(2012,1,1)), date2num(datetime(2015,1,1)), 
           label="2012–2014 European Debt Crisis", color="orange", alpha=0.1)
plt.legend()

# Aesthetics
matplotlib.pyplot.grid(visible=True, which='both', axis='both', color='blue', alpha=0.1, linestyle='--', linewidth=1)

plt.gca().spines['top'].set_visible(False)
plt.gca().spines['right'].set_visible(False)
plt.tight_layout()

# Save and show
plt.savefig("/Users/minoperic/Data Analytics/Data Investigations/global-economic-indicators/Images/bsl_australia.png", dpi=300)
plt.show()

# %%
# Plotting – BSL (Canada)

# Font families
font_1 = {'family':'helvetica','color':'black','size':16}
font_2 = {'family':'helvetica','color':'black','size':12}

# Plot
plt.figure(figsize=(15,5))
plt.plot(can_bsl_df['TIME'], can_bsl_df['VALUE'], color='blue', linewidth=3)

# Labels
plt.title("Banking Sector Leverage (Equity Multiplier Ratio) – Canada, yearly average (1995–2020)", fontdict = font_1)
plt.xlabel("Year", fontdict = font_2)
plt.ylabel("% of net value added", fontdict = font_2)

# Highlights
plt.axvspan(date2num(datetime(2007,1,1)), date2num(datetime(2009,1,1)), 
           label="2008 Global Financial Crisis", color="red", alpha=0.1)

plt.axvspan(date2num(datetime(2012,1,1)), date2num(datetime(2015,1,1)), 
           label="2012–2014 European Debt Crisis", color="orange", alpha=0.1)
plt.legend()

# Aesthetics
matplotlib.pyplot.grid(visible=True, which='both', axis='both', color='blue', alpha=0.1, linestyle='--', linewidth=1)

plt.gca().spines['top'].set_visible(False)
plt.gca().spines['right'].set_visible(False)
plt.tight_layout()

# Save and show
plt.savefig("/Users/minoperic/Data Analytics/Data Investigations/global-economic-indicators/Images/bsl_canada.png", dpi=300)
plt.show()

# %%
# Plotting – BSL (Germany)

# Font families
font_1 = {'family':'helvetica','color':'black','size':16}
font_2 = {'family':'helvetica','color':'black','size':12}

# Plot
plt.figure(figsize=(15,5))
plt.plot(deu_bsl_df['TIME'], deu_bsl_df['VALUE'], color='blue', linewidth=3)

# Labels
plt.title("Banking Sector Leverage (Equity Multiplier Ratio) – Germany, yearly average (1995–2020)", fontdict = font_1)
plt.xlabel("Year", fontdict = font_2)
plt.ylabel("% of net value added", fontdict = font_2)

# Highlights
plt.axvspan(date2num(datetime(2007,1,1)), date2num(datetime(2009,1,1)), 
           label="2008 Global Financial Crisis", color="red", alpha=0.1)

plt.axvspan(date2num(datetime(2012,1,1)), date2num(datetime(2015,1,1)), 
           label="2012–2014 European Debt Crisis", color="orange", alpha=0.1)
plt.legend()

# Aesthetics
matplotlib.pyplot.grid(visible=True, which='both', axis='both', color='blue', alpha=0.1, linestyle='--', linewidth=1)

plt.gca().spines['top'].set_visible(False)
plt.gca().spines['right'].set_visible(False)
plt.tight_layout()

# Save and show
plt.savefig("/Users/minoperic/Data Analytics/Data Investigations/global-economic-indicators/Images/bsl_germany.png", dpi=300)
plt.show()

# %%
# Plotting – BSL (France)

# Font families
font_1 = {'family':'helvetica','color':'black','size':16}
font_2 = {'family':'helvetica','color':'black','size':12}

# Plot
plt.figure(figsize=(15,5))
plt.plot(fra_bsl_df['TIME'], fra_bsl_df['VALUE'], color='blue', linewidth=3)

# Labels
plt.title("Banking Sector Leverage (Equity Multiplier Ratio) – France, yearly average (1995–2020)", fontdict = font_1)
plt.xlabel("Year", fontdict = font_2)
plt.ylabel("% of net value added", fontdict = font_2)

# Highlights
plt.axvspan(date2num(datetime(2007,1,1)), date2num(datetime(2009,1,1)), 
           label="2008 Global Financial Crisis", color="red", alpha=0.1)

plt.axvspan(date2num(datetime(2012,1,1)), date2num(datetime(2015,1,1)), 
           label="2012–2014 European Debt Crisis", color="orange", alpha=0.1)
plt.legend()

# Aesthetics
matplotlib.pyplot.grid(visible=True, which='both', axis='both', color='blue', alpha=0.1, linestyle='--', linewidth=1)

plt.gca().spines['top'].set_visible(False)
plt.gca().spines['right'].set_visible(False)
plt.tight_layout()

# Save and show
plt.savefig("/Users/minoperic/Data Analytics/Data Investigations/global-economic-indicators/Images/bsl_france.png", dpi=300)
plt.show()

# %%
# Plotting – BSL (Great Britain)

# Font families
font_1 = {'family':'helvetica','color':'black','size':16}
font_2 = {'family':'helvetica','color':'black','size':12}

# Plot
plt.figure(figsize=(15,5))
plt.plot(gbr_bsl_df['TIME'], gbr_bsl_df['VALUE'], color='blue', linewidth=3)

# Labels
plt.title("Banking Sector Leverage (Equity Multiplier Ratio) – Great Britain, yearly average (1995–2020)", fontdict = font_1)
plt.xlabel("Year", fontdict = font_2)
plt.ylabel("% of net value added", fontdict = font_2)

# Highlights
plt.axvspan(date2num(datetime(2007,1,1)), date2num(datetime(2009,1,1)), 
           label="2008 Global Financial Crisis", color="red", alpha=0.1)

plt.axvspan(date2num(datetime(2012,1,1)), date2num(datetime(2015,1,1)), 
           label="2012–2014 European Debt Crisis", color="orange", alpha=0.1)
plt.legend()

# Aesthetics
matplotlib.pyplot.grid(visible=True, which='both', axis='both', color='blue', alpha=0.1, linestyle='--', linewidth=1)

plt.gca().spines['top'].set_visible(False)
plt.gca().spines['right'].set_visible(False)
plt.tight_layout()

# Save and show
plt.savefig("/Users/minoperic/Data Analytics/Data Investigations/global-economic-indicators/Images/bsl_great_britain.png", dpi=300)
plt.show()

# %%
# Plotting – BSL (Italy)

# Font families
font_1 = {'family':'helvetica','color':'black','size':16}
font_2 = {'family':'helvetica','color':'black','size':12}

# Plot
plt.figure(figsize=(15,5))
plt.plot(ita_bsl_df['TIME'], ita_bsl_df['VALUE'], color='blue', linewidth=3)

# Labels
plt.title("Banking Sector Leverage (Equity Multiplier Ratio) – Italy, yearly average (1995–2020)", fontdict = font_1)
plt.xlabel("Year", fontdict = font_2)
plt.ylabel("% of net value added", fontdict = font_2)

# Highlights
plt.axvspan(date2num(datetime(2007,1,1)), date2num(datetime(2009,1,1)), 
           label="2008 Global Financial Crisis", color="red", alpha=0.1)

plt.axvspan(date2num(datetime(2012,1,1)), date2num(datetime(2015,1,1)), 
           label="2012–2014 European Debt Crisis", color="orange", alpha=0.1)
plt.legend()

# Aesthetics
matplotlib.pyplot.grid(visible=True, which='both', axis='both', color='blue', alpha=0.1, linestyle='--', linewidth=1)

plt.gca().spines['top'].set_visible(False)
plt.gca().spines['right'].set_visible(False)
plt.tight_layout()

# Save and show
plt.savefig("/Users/minoperic/Data Analytics/Data Investigations/global-economic-indicators/Images/bsl_italy.png", dpi=300)
plt.show()

# %%
# Plotting – BSL (Japan)

# Font families
font_1 = {'family':'helvetica','color':'black','size':16}
font_2 = {'family':'helvetica','color':'black','size':12}

# Plot
plt.figure(figsize=(15,5))
plt.plot(jpn_bsl_df['TIME'], jpn_bsl_df['VALUE'], color='blue', linewidth=3)

# Labels
plt.title("Banking Sector Leverage (Equity Multiplier Ratio) – Japan, yearly average (1995–2020)", fontdict = font_1)
plt.xlabel("Year", fontdict = font_2)
plt.ylabel("% of net value added", fontdict = font_2)

# Highlights
plt.axvspan(date2num(datetime(2007,1,1)), date2num(datetime(2009,1,1)), 
           label="2008 Global Financial Crisis", color="red", alpha=0.1)

plt.axvspan(date2num(datetime(2012,1,1)), date2num(datetime(2015,1,1)), 
           label="2012–2014 European Debt Crisis", color="orange", alpha=0.1)

plt.legend()

# Aesthetics
matplotlib.pyplot.grid(visible=True, which='both', axis='both', color='blue', alpha=0.1, linestyle='--', linewidth=1)

plt.gca().spines['top'].set_visible(False)
plt.gca().spines['right'].set_visible(False)
plt.tight_layout()

# Save and show
plt.savefig("/Users/minoperic/Data Analytics/Data Investigations/global-economic-indicators/Images/bsl_japan.png", dpi=300)
plt.show()

# %%
# Plotting – BSL (USA)

# Font families
font_1 = {'family':'helvetica','color':'black','size':16}
font_2 = {'family':'helvetica','color':'black','size':12}

# Plot
plt.figure(figsize=(15,5))
plt.plot(usa_bsl_df['TIME'], usa_bsl_df['VALUE'], color='blue', linewidth=3)

# Labels
plt.title("Banking Sector Leverage (Equity Multiplier Ratio) – USA, yearly average (1995–2020)", fontdict = font_1)
plt.xlabel("Year", fontdict = font_2)
plt.ylabel("% of net value added", fontdict = font_2)

# Highlights

plt.axvspan(date2num(datetime(2007,1,1)), date2num(datetime(2009,1,1)), 
           label="2008 Global Financial Crisis", color="red", alpha=0.1)

plt.axvspan(date2num(datetime(2012,1,1)), date2num(datetime(2015,1,1)), 
           label="2012–2014 European Debt Crisis", color="orange", alpha=0.1)

plt.legend()

# Aesthetics

matplotlib.pyplot.grid(visible=True, which='both', axis='both', color='blue', alpha=0.1, linestyle='--', linewidth=1)

plt.gca().spines['top'].set_visible(False)
plt.gca().spines['right'].set_visible(False)
plt.tight_layout()

# Save and show
plt.savefig("/Users/minoperic/Data Analytics/Data Investigations/global-economic-indicators/Images/bsl_usa.png", dpi=300)
plt.show()

# %%
## Business Confidence Index (BCI)

# %%
# Create new DataFrames based on locations (countries)

# bci_df['LOCATION'].unique()
    
aus_bci_df = bci_df[bci_df.LOCATION == 'AUS'] #Australia
can_bci_df = bci_df[bci_df.LOCATION == 'CAN'] #Canada
deu_bci_df = bci_df[bci_df.LOCATION == 'DEU'] #Germany
fra_bci_df = bci_df[bci_df.LOCATION == 'FRA'] #France
gbr_bci_df = bci_df[bci_df.LOCATION == 'GBR'] #Great Britain
ita_bci_df = bci_df[bci_df.LOCATION == 'ITA'] #Italy
jpn_bci_df = bci_df[bci_df.LOCATION == 'JPN'] #Japan
oecd_bci_df = bci_df[bci_df.LOCATION == 'OECD'] #OECD
rus_bci_df = bci_df[bci_df.LOCATION == 'RUS'] #RUS
usa_bci_df = bci_df[bci_df.LOCATION == 'USA'] #USA

bci_df
# Out:
#      LOCATION       TIME     VALUE
# 0         AUS 1970-02-01  101.2701
# 1         AUS 1970-03-01  100.9276
# 2         AUS 1970-04-01  100.4837
# 3         AUS 1970-05-01  100.1568
# 4         AUS 1970-06-01  100.1140
# ...       ...        ...       ...
# 5358      USA 2021-09-01  101.6754
# 5359      USA 2021-10-01  101.6969
# 5360      USA 2021-11-01  101.5930
# 5361      USA 2021-12-01  101.3199
# 5362      USA 2022-01-01  101.0102
#
# [5363 rows x 3 columns]

# %%
# Plotting – BCI (Australia)

# Font families
font_1 = {'family':'helvetica','color':'black','size':16}
font_2 = {'family':'helvetica','color':'black','size':12}

# Plot
plt.figure(figsize=(15,5))
plt.plot(aus_bci_df['TIME'], aus_bci_df['VALUE'], color='blue', linewidth=3)

# Labels
plt.title("Business Confidence Index (BCI) – Australia, amplitude adjusted (1970–2022)", fontdict = font_1)
plt.xlabel("Year", fontdict = font_2)
plt.ylabel("Long-term Average = 100", fontdict = font_2)

# Highlights
plt.axvspan(date2num(datetime(2020,1,1)), date2num(datetime(2023,1,1)), 
           label="2020 COVID-19 Pandemic", color="green", alpha=0.1)
plt.axvspan(date2num(datetime(2007,1,1)), date2num(datetime(2009,1,1)), 
           label="2008 Global Financial Crisis", color="red", alpha=0.1)
plt.axvspan(date2num(datetime(2012,1,1)), date2num(datetime(2015,1,1)), 
           label="2012–2014 European Debt Crisis", color="orange", alpha=0.1)
plt.axvspan(date2num(datetime(1987,1,1)), date2num(datetime(1990,1,1)), 
           label="1987 Stock Market Crash", color="blue", alpha=0.1)
plt.axvspan(date2num(datetime(1973,1,1)), date2num(datetime(1975,1,1)), 
           label="1973–1974 Stock Market Crash", color="purple", alpha=0.1)
plt.legend()

# Aesthetics
matplotlib.pyplot.grid(visible=True, which='both', axis='both', color='blue', alpha=0.1, linestyle='--', linewidth=1)

plt.gca().spines['top'].set_visible(False)
plt.gca().spines['right'].set_visible(False)
plt.tight_layout()

# Save and show
plt.savefig("/Users/minoperic/Data Analytics/Data Investigations/global-economic-indicators/Images/bci_australia.png", dpi=300)
plt.show()

# %%
# Plotting – BCI (Canada)

# Font families
font_1 = {'family':'helvetica','color':'black','size':16}
font_2 = {'family':'helvetica','color':'black','size':12}

# Plot
plt.figure(figsize=(15,5))
plt.plot(can_bci_df['TIME'], can_bci_df['VALUE'], color='blue', linewidth=3)

# Labels
plt.title("Business Confidence Index (BCI) – Canada, amplitude adjusted (1970–2022)", fontdict = font_1)
plt.xlabel("Year", fontdict = font_2)
plt.ylabel("Long-term Average = 100", fontdict = font_2)

# Highlights
plt.axvspan(date2num(datetime(2020,1,1)), date2num(datetime(2023,1,1)), 
           label="2020 COVID-19 Pandemic", color="green", alpha=0.1)
plt.axvspan(date2num(datetime(2007,1,1)), date2num(datetime(2009,1,1)), 
           label="2008 Global Financial Crisis", color="red", alpha=0.1)
plt.axvspan(date2num(datetime(2012,1,1)), date2num(datetime(2015,1,1)), 
           label="2012–2014 European Debt Crisis", color="orange", alpha=0.1)
plt.axvspan(date2num(datetime(1987,1,1)), date2num(datetime(1990,1,1)), 
           label="1987 Stock Market Crash", color="blue", alpha=0.1)
plt.axvspan(date2num(datetime(1973,1,1)), date2num(datetime(1975,1,1)), 
           label="1973–1974 Stock Market Crash", color="purple", alpha=0.1)
plt.legend()

# Aesthetics
matplotlib.pyplot.grid(visible=True, which='both', axis='both', color='blue', alpha=0.1, linestyle='--', linewidth=1)

plt.gca().spines['top'].set_visible(False)
plt.gca().spines['right'].set_visible(False)
plt.tight_layout()

# Save and show
plt.savefig("/Users/minoperic/Data Analytics/Data Investigations/global-economic-indicators/Images/bci_canada.png", dpi=300)
plt.show()

# %%
# Plotting – BCI (Germany)

# Font families
font_1 = {'family':'helvetica','color':'black','size':16}
font_2 = {'family':'helvetica','color':'black','size':12}

# Plot
plt.figure(figsize=(15,5))
plt.plot(deu_bci_df['TIME'], deu_bci_df['VALUE'], color='blue', linewidth=3)

# Labels
plt.title("Business Confidence Index (BCI) – Germany, amplitude adjusted (1970–2022)", fontdict = font_1)
plt.xlabel("Year", fontdict = font_2)
plt.ylabel("Long-term Average = 100", fontdict = font_2)

# Highlights
plt.axvspan(date2num(datetime(2020,1,1)), date2num(datetime(2023,1,1)), 
           label="2020 COVID-19 Pandemic", color="green", alpha=0.1)
plt.axvspan(date2num(datetime(2007,1,1)), date2num(datetime(2009,1,1)), 
           label="2008 Global Financial Crisis", color="red", alpha=0.1)
plt.axvspan(date2num(datetime(2012,1,1)), date2num(datetime(2015,1,1)), 
           label="2012–2014 European Debt Crisis", color="orange", alpha=0.1)
plt.axvspan(date2num(datetime(1987,1,1)), date2num(datetime(1990,1,1)), 
           label="1987 Stock Market Crash", color="blue", alpha=0.1)
plt.axvspan(date2num(datetime(1973,1,1)), date2num(datetime(1975,1,1)), 
           label="1973–1974 Stock Market Crash", color="purple", alpha=0.1)
plt.legend()

# Aesthetics
matplotlib.pyplot.grid(visible=True, which='both', axis='both', color='blue', alpha=0.1, linestyle='--', linewidth=1)

plt.gca().spines['top'].set_visible(False)
plt.gca().spines['right'].set_visible(False)
plt.tight_layout()

# Save and show
plt.savefig("/Users/minoperic/Data Analytics/Data Investigations/global-economic-indicators/Images/bci_germany.png", dpi=300)
plt.show()

# %%
# Plotting – BCI (France)

# Font families
font_1 = {'family':'helvetica','color':'black','size':16}
font_2 = {'family':'helvetica','color':'black','size':12}

# Plot
plt.figure(figsize=(15,5))
plt.plot(fra_bci_df['TIME'], fra_bci_df['VALUE'], color='blue', linewidth=3)

# Labels
plt.title("Business Confidence Index (BCI) – France, amplitude adjusted (1970–2022)", fontdict = font_1)
plt.xlabel("Year", fontdict = font_2)
plt.ylabel("Long-term Average = 100", fontdict = font_2)

# Highlights
plt.axvspan(date2num(datetime(2020,1,1)), date2num(datetime(2023,1,1)), 
           label="2020 COVID-19 Pandemic", color="green", alpha=0.1)
plt.axvspan(date2num(datetime(2007,1,1)), date2num(datetime(2009,1,1)), 
           label="2008 Global Financial Crisis", color="red", alpha=0.1)
plt.axvspan(date2num(datetime(2012,1,1)), date2num(datetime(2015,1,1)), 
           label="2012–2014 European Debt Crisis", color="orange", alpha=0.1)
plt.axvspan(date2num(datetime(1987,1,1)), date2num(datetime(1990,1,1)), 
           label="1987 Stock Market Crash", color="blue", alpha=0.1)
# plt.axvspan(date2num(datetime(1973,1,1)), date2num(datetime(1975,1,1)), 
#            label="1973–1974 Stock Market Crash", color="purple", alpha=0.1)
plt.legend()

# Aesthetics
matplotlib.pyplot.grid(visible=True, which='both', axis='both', color='blue', alpha=0.1, linestyle='--', linewidth=1)

plt.gca().spines['top'].set_visible(False)
plt.gca().spines['right'].set_visible(False)
plt.tight_layout()

# Save and show
plt.savefig("/Users/minoperic/Data Analytics/Data Investigations/global-economic-indicators/Images/bci_france.png", dpi=300)
plt.show()

# %%
# Plotting – BCI (Great Britain)

# Font families
font_1 = {'family':'helvetica','color':'black','size':16}
font_2 = {'family':'helvetica','color':'black','size':12}

# Plot
plt.figure(figsize=(15,5))
plt.plot(gbr_bci_df['TIME'], gbr_bci_df['VALUE'], color='blue', linewidth=3)

# Labels
plt.title("Business Confidence Index (BCI) – Great Britain, amplitude adjusted (1970–2022)", fontdict = font_1)
plt.xlabel("Year", fontdict = font_2)
plt.ylabel("Long-term Average = 100", fontdict = font_2)

# Highlights
plt.axvspan(date2num(datetime(2020,1,1)), date2num(datetime(2023,1,1)), 
           label="2020 COVID-19 Pandemic", color="green", alpha=0.1)
plt.axvspan(date2num(datetime(2007,1,1)), date2num(datetime(2009,1,1)), 
           label="2008 Global Financial Crisis", color="red", alpha=0.1)
plt.axvspan(date2num(datetime(2012,1,1)), date2num(datetime(2015,1,1)), 
           label="2012–2014 European Debt Crisis", color="orange", alpha=0.1)
plt.axvspan(date2num(datetime(1987,1,1)), date2num(datetime(1990,1,1)), 
           label="1987 Stock Market Crash", color="blue", alpha=0.1)
# plt.axvspan(date2num(datetime(1973,1,1)), date2num(datetime(1975,1,1)), 
#            label="1973–1974 Stock Market Crash", color="purple", alpha=0.1)
plt.legend()

# Aesthetics
matplotlib.pyplot.grid(visible=True, which='both', axis='both', color='blue', alpha=0.1, linestyle='--', linewidth=1)

plt.gca().spines['top'].set_visible(False)
plt.gca().spines['right'].set_visible(False)
plt.tight_layout()

# Save and show
plt.savefig("/Users/minoperic/Data Analytics/Data Investigations/global-economic-indicators/Images/bci_great_britain.png", dpi=300)
plt.show()

# %%
# Plotting – BCI (Italy)

# Font families
font_1 = {'family':'helvetica','color':'black','size':16}
font_2 = {'family':'helvetica','color':'black','size':12}

# Plot
plt.figure(figsize=(15,5))
plt.plot(ita_bci_df['TIME'], ita_bci_df['VALUE'], color='blue', linewidth=3)

# Labels
plt.title("Business Confidence Index (BCI) – Italy, amplitude adjusted (1970–2022)", fontdict = font_1)
plt.xlabel("Year", fontdict = font_2)
plt.ylabel("Long-term Average = 100", fontdict = font_2)

# Highlights
plt.axvspan(date2num(datetime(2020,1,1)), date2num(datetime(2023,1,1)), 
           label="2020 COVID-19 Pandemic", color="green", alpha=0.1)
plt.axvspan(date2num(datetime(2007,1,1)), date2num(datetime(2009,1,1)), 
           label="2008 Global Financial Crisis", color="red", alpha=0.1)
plt.axvspan(date2num(datetime(2012,1,1)), date2num(datetime(2015,1,1)), 
           label="2012–2014 European Debt Crisis", color="orange", alpha=0.1)
plt.axvspan(date2num(datetime(1987,1,1)), date2num(datetime(1990,1,1)), 
           label="1987 Stock Market Crash", color="blue", alpha=0.1)
plt.axvspan(date2num(datetime(1973,1,1)), date2num(datetime(1975,1,1)), 
           label="1973–1974 Stock Market Crash", color="purple", alpha=0.1)
plt.legend()

# Aesthetics
matplotlib.pyplot.grid(visible=True, which='both', axis='both', color='blue', alpha=0.1, linestyle='--', linewidth=1)

plt.gca().spines['top'].set_visible(False)
plt.gca().spines['right'].set_visible(False)
plt.tight_layout()

# Save and show
plt.savefig("/Users/minoperic/Data Analytics/Data Investigations/global-economic-indicators/Images/bci_italy.png", dpi=300)
plt.show()

# %%
# Plotting – BCI (Japan)

# Font families
font_1 = {'family':'helvetica','color':'black','size':16}
font_2 = {'family':'helvetica','color':'black','size':12}

# Plot
plt.figure(figsize=(15,5))
plt.plot(jpn_bci_df['TIME'], jpn_bci_df['VALUE'], color='blue', linewidth=3)

# Labels
plt.title("Business Confidence Index (BCI) – Japan, amplitude adjusted (1970–2022)", fontdict = font_1)
plt.xlabel("Year", fontdict = font_2)
plt.ylabel("Long-term Average = 100", fontdict = font_2)

# Highlights
plt.axvspan(date2num(datetime(2020,1,1)), date2num(datetime(2023,1,1)), 
           label="2020 COVID-19 Pandemic", color="green", alpha=0.1)
plt.axvspan(date2num(datetime(2007,1,1)), date2num(datetime(2009,1,1)), 
           label="2008 Global Financial Crisis", color="red", alpha=0.1)
plt.axvspan(date2num(datetime(2012,1,1)), date2num(datetime(2015,1,1)), 
           label="2012–2014 European Debt Crisis", color="orange", alpha=0.1)
plt.axvspan(date2num(datetime(1987,1,1)), date2num(datetime(1990,1,1)), 
           label="1987 Stock Market Crash", color="blue", alpha=0.1)
plt.axvspan(date2num(datetime(1973,1,1)), date2num(datetime(1975,1,1)), 
           label="1973–1974 Stock Market Crash", color="purple", alpha=0.1)
plt.legend()

# Aesthetics
matplotlib.pyplot.grid(visible=True, which='both', axis='both', color='blue', alpha=0.1, linestyle='--', linewidth=1)

plt.gca().spines['top'].set_visible(False)
plt.gca().spines['right'].set_visible(False)
plt.tight_layout()

# Save and show
plt.savefig("/Users/minoperic/Data Analytics/Data Investigations/global-economic-indicators/Images/bci_japan.png", dpi=300)
plt.show()

# %%
# Plotting – BCI (OECD)

# Font families
font_1 = {'family':'helvetica','color':'black','size':16}
font_2 = {'family':'helvetica','color':'black','size':12}

# Plot
plt.figure(figsize=(15,5))
plt.plot(oecd_bci_df['TIME'], oecd_bci_df['VALUE'], color='blue', linewidth=3)

# Labels
plt.title("Business Confidence Index (BCI) – OECD, amplitude adjusted (1970–2022)", fontdict = font_1)
plt.xlabel("Year", fontdict = font_2)
plt.ylabel("Long-term Average = 100", fontdict = font_2)

# Highlights
plt.axvspan(date2num(datetime(2020,1,1)), date2num(datetime(2023,1,1)), 
           label="2020 COVID-19 Pandemic", color="green", alpha=0.1)
plt.axvspan(date2num(datetime(2007,1,1)), date2num(datetime(2009,1,1)), 
           label="2008 Global Financial Crisis", color="red", alpha=0.1)
plt.axvspan(date2num(datetime(2012,1,1)), date2num(datetime(2015,1,1)), 
           label="2012–2014 European Debt Crisis", color="orange", alpha=0.1)
plt.axvspan(date2num(datetime(1987,1,1)), date2num(datetime(1990,1,1)), 
           label="1987 Stock Market Crash", color="blue", alpha=0.1)
plt.axvspan(date2num(datetime(1973,1,1)), date2num(datetime(1975,1,1)), 
           label="1973–1974 Stock Market Crash", color="purple", alpha=0.1)
plt.legend()

# Aesthetics
matplotlib.pyplot.grid(visible=True, which='both', axis='both', color='blue', alpha=0.1, linestyle='--', linewidth=1)

plt.gca().spines['top'].set_visible(False)
plt.gca().spines['right'].set_visible(False)
plt.tight_layout()

# Save and show
plt.savefig("/Users/minoperic/Data Analytics/Data Investigations/global-economic-indicators/Images/bci_oecd.png", dpi=300)
plt.show()

# %%
# Plotting – BCI (Russia)

# Font families
font_1 = {'family':'helvetica','color':'black','size':16}
font_2 = {'family':'helvetica','color':'black','size':12}

# Plot
plt.figure(figsize=(15,5))
plt.plot(rus_bci_df['TIME'], rus_bci_df['VALUE'], color='blue', linewidth=3)

# Labels
plt.title("Business Confidence Index (BCI) – Russia, amplitude adjusted (1970–2022)", fontdict = font_1)
plt.xlabel("Year", fontdict = font_2)
plt.ylabel("Long-term Average = 100", fontdict = font_2)

# Highlights
plt.axvspan(date2num(datetime(2020,1,1)), date2num(datetime(2023,1,1)), 
           label="2020 COVID-19 Pandemic", color="green", alpha=0.1)
plt.axvspan(date2num(datetime(2007,1,1)), date2num(datetime(2009,1,1)), 
           label="2008 Global Financial Crisis", color="red", alpha=0.1)
plt.axvspan(date2num(datetime(2012,1,1)), date2num(datetime(2015,1,1)), 
           label="2012–2014 European Debt Crisis", color="orange", alpha=0.1)
# plt.axvspan(date2num(datetime(1987,1,1)), date2num(datetime(1990,1,1)), 
#            label="1987 Stock Market Crash", color="blue", alpha=0.1)
# plt.axvspan(date2num(datetime(1973,1,1)), date2num(datetime(1975,1,1)), 
#            label="1973–1974 Stock Market Crash", color="purple", alpha=0.1)
plt.legend()

# Aesthetics
matplotlib.pyplot.grid(visible=True, which='both', axis='both', color='blue', alpha=0.1, linestyle='--', linewidth=1)

plt.gca().spines['top'].set_visible(False)
plt.gca().spines['right'].set_visible(False)
plt.tight_layout()

# Save and show
plt.savefig("/Users/minoperic/Data Analytics/Data Investigations/global-economic-indicators/Images/bci_russia.png", dpi=300)
plt.show()

# %%
# Plotting – BCI (USA)

# Font families
font_1 = {'family':'helvetica','color':'black','size':16}
font_2 = {'family':'helvetica','color':'black','size':12}

# Plot
plt.figure(figsize=(15,5))
plt.plot(usa_bci_df['TIME'], usa_bci_df['VALUE'], color='blue', linewidth=3)

# Labels
plt.title("Business Confidence Index (BCI) – USA, amplitude adjusted (1970–2022)", fontdict = font_1)
plt.xlabel("Year", fontdict = font_2)
plt.ylabel("Long-term Average = 100", fontdict = font_2)

# Highlights
plt.axvspan(date2num(datetime(2020,1,1)), date2num(datetime(2023,1,1)), 
           label="2020 COVID-19 Pandemic", color="green", alpha=0.1)
plt.axvspan(date2num(datetime(2007,1,1)), date2num(datetime(2009,1,1)), 
           label="2008 Global Financial Crisis", color="red", alpha=0.1)
plt.axvspan(date2num(datetime(2012,1,1)), date2num(datetime(2015,1,1)), 
           label="2012–2014 European Debt Crisis", color="orange", alpha=0.1)
plt.axvspan(date2num(datetime(1987,1,1)), date2num(datetime(1990,1,1)), 
           label="1987 Stock Market Crash", color="blue", alpha=0.1)
plt.axvspan(date2num(datetime(1973,1,1)), date2num(datetime(1975,1,1)), 
           label="1973–1974 Stock Market Crash", color="purple", alpha=0.1)
plt.legend()

# Aesthetics
matplotlib.pyplot.grid(visible=True, which='both', axis='both', color='blue', alpha=0.1, linestyle='--', linewidth=1)

plt.gca().spines['top'].set_visible(False)
plt.gca().spines['right'].set_visible(False)
plt.tight_layout()

# Save and show
plt.savefig("/Users/minoperic/Data Analytics/Data Investigations/global-economic-indicators/Images/bci_usa.png", dpi=300)
plt.show()

# %%
## Composite Leading Indicator (CLI)

# %%
# Create new DataFrames based on locations (countries)

# cli_df['LOCATION'].unique()
    
aus_cli_df = cli_df[cli_df.LOCATION == 'AUS'] #Australia
can_cli_df = cli_df[cli_df.LOCATION == 'CAN'] #Canada
deu_cli_df = cli_df[cli_df.LOCATION == 'DEU'] #Germany
fra_cli_df = cli_df[cli_df.LOCATION == 'FRA'] #France
gbr_cli_df = cli_df[cli_df.LOCATION == 'GBR'] #Great Britain
ita_cli_df = cli_df[cli_df.LOCATION == 'ITA'] #Italy
jpn_cli_df = cli_df[cli_df.LOCATION == 'JPN'] #Japan
oecd_cli_df = cli_df[cli_df.LOCATION == 'OECD'] #OECD
rus_cli_df = cli_df[cli_df.LOCATION == 'RUS'] #Russia
usa_cli_df = cli_df[cli_df.LOCATION == 'USA'] #USA

cli_df
# Out:
#      LOCATION       TIME      VALUE
# 0         AUS 1970-02-01  100.65840
# 1         AUS 1970-03-01  100.34890
# 2         AUS 1970-04-01  100.03390
# 3         AUS 1970-05-01   99.77695
# 4         AUS 1970-06-01   99.60847
# ...       ...        ...        ...
# 5964      USA 2021-09-01  100.19270
# 5965      USA 2021-10-01  100.09680
# 5966      USA 2021-11-01  100.02060
# 5967      USA 2021-12-01   99.95236
# 5968      USA 2022-01-01   99.88610
#
# [5969 rows x 3 columns]

# %%
# Plotting – CLI (Australia)

# Font families
font_1 = {'family':'helvetica','color':'black','size':16}
font_2 = {'family':'helvetica','color':'black','size':12}

# Plot
plt.figure(figsize=(15,5))
plt.plot(aus_cli_df['TIME'], aus_cli_df['VALUE'], color='blue', linewidth=3)

# Labels
plt.title("Consumer Leading Indicator (CLI) – Australia, amplitude adjusted (1970–2022)", fontdict = font_1)
plt.xlabel("Year", fontdict = font_2)
plt.ylabel("Long-term Average = 100", fontdict = font_2)

# Highlights
plt.axvspan(date2num(datetime(2020,1,1)), date2num(datetime(2023,1,1)), 
           label="2020 COVID-19 Pandemic", color="green", alpha=0.1)
plt.axvspan(date2num(datetime(2007,1,1)), date2num(datetime(2009,1,1)), 
           label="2008 Global Financial Crisis", color="red", alpha=0.1)
plt.axvspan(date2num(datetime(2012,1,1)), date2num(datetime(2015,1,1)), 
           label="2012–2014 European Debt Crisis", color="orange", alpha=0.1)
plt.axvspan(date2num(datetime(1987,1,1)), date2num(datetime(1990,1,1)), 
           label="1987 Stock Market Crash", color="blue", alpha=0.1)
plt.axvspan(date2num(datetime(1973,1,1)), date2num(datetime(1975,1,1)), 
           label="1973–1974 Stock Market Crash", color="purple", alpha=0.1)
plt.legend()

# Aesthetics
matplotlib.pyplot.grid(visible=True, which='both', axis='both', color='blue', alpha=0.1, linestyle='--', linewidth=1)

plt.gca().spines['top'].set_visible(False)
plt.gca().spines['right'].set_visible(False)
plt.tight_layout()

# Save and show
plt.savefig("/Users/minoperic/Data Analytics/Data Investigations/global-economic-indicators/Images/cli_australia.png", dpi=300)
plt.show()

# %%
# Plotting – CLI (Canada)

# Font families
font_1 = {'family':'helvetica','color':'black','size':16}
font_2 = {'family':'helvetica','color':'black','size':12}

# Plot
plt.figure(figsize=(15,5))
plt.plot(can_cli_df['TIME'], can_cli_df['VALUE'], color='blue', linewidth=3)

# Labels
plt.title("Consumer Leading Indicator (CLI) – Canada, amplitude adjusted (1970–2022)", fontdict = font_1)
plt.xlabel("Year", fontdict = font_2)
plt.ylabel("Long-term Average = 100", fontdict = font_2)

# Highlights
plt.axvspan(date2num(datetime(2020,1,1)), date2num(datetime(2023,1,1)), 
           label="2020 COVID-19 Pandemic", color="green", alpha=0.1)
plt.axvspan(date2num(datetime(2007,1,1)), date2num(datetime(2009,1,1)), 
           label="2008 Global Financial Crisis", color="red", alpha=0.1)
plt.axvspan(date2num(datetime(2012,1,1)), date2num(datetime(2015,1,1)), 
           label="2012–2014 European Debt Crisis", color="orange", alpha=0.1)
plt.axvspan(date2num(datetime(1987,1,1)), date2num(datetime(1990,1,1)), 
           label="1987 Stock Market Crash", color="blue", alpha=0.1)
plt.axvspan(date2num(datetime(1973,1,1)), date2num(datetime(1975,1,1)), 
           label="1973–1974 Stock Market Crash", color="purple", alpha=0.1)
plt.legend()

# Aesthetics
matplotlib.pyplot.grid(visible=True, which='both', axis='both', color='blue', alpha=0.1, linestyle='--', linewidth=1)

plt.gca().spines['top'].set_visible(False)
plt.gca().spines['right'].set_visible(False)
plt.tight_layout()

# Save and show
plt.savefig("/Users/minoperic/Data Analytics/Data Investigations/global-economic-indicators/Images/cli_canada.png", dpi=300)
plt.show()

# %%
# Plotting – CLI (Germany)

# Font families
font_1 = {'family':'helvetica','color':'black','size':16}
font_2 = {'family':'helvetica','color':'black','size':12}

# Plot
plt.figure(figsize=(15,5))
plt.plot(deu_cli_df['TIME'], deu_cli_df['VALUE'], color='blue', linewidth=3)

# Labels
plt.title("Consumer Leading Indicator (CLI) – Germany, amplitude adjusted (1970–2022)", fontdict = font_1)
plt.xlabel("Year", fontdict = font_2)
plt.ylabel("Long-term Average = 100", fontdict = font_2)

# Highlights
plt.axvspan(date2num(datetime(2020,1,1)), date2num(datetime(2023,1,1)), 
           label="2020 COVID-19 Pandemic", color="green", alpha=0.1)
plt.axvspan(date2num(datetime(2007,1,1)), date2num(datetime(2009,1,1)), 
           label="2008 Global Financial Crisis", color="red", alpha=0.1)
plt.axvspan(date2num(datetime(2012,1,1)), date2num(datetime(2015,1,1)), 
           label="2012–2014 European Debt Crisis", color="orange", alpha=0.1)
plt.axvspan(date2num(datetime(1987,1,1)), date2num(datetime(1990,1,1)), 
           label="1987 Stock Market Crash", color="blue", alpha=0.1)
plt.axvspan(date2num(datetime(1973,1,1)), date2num(datetime(1975,1,1)), 
           label="1973–1974 Stock Market Crash", color="purple", alpha=0.1)
plt.legend()

# Aesthetics
matplotlib.pyplot.grid(visible=True, which='both', axis='both', color='blue', alpha=0.1, linestyle='--', linewidth=1)

plt.gca().spines['top'].set_visible(False)
plt.gca().spines['right'].set_visible(False)
plt.tight_layout()

# Save and show
plt.savefig("/Users/minoperic/Data Analytics/Data Investigations/global-economic-indicators/Images/cli_germany.png", dpi=300)
plt.show()

# %%
# Plotting – CLI (France)

# Font families
font_1 = {'family':'helvetica','color':'black','size':16}
font_2 = {'family':'helvetica','color':'black','size':12}

# Plot
plt.figure(figsize=(15,5))
plt.plot(fra_cli_df['TIME'], fra_cli_df['VALUE'], color='blue', linewidth=3)

# Labels
plt.title("Consumer Leading Indicator (CLI) – France, amplitude adjusted (1970–2022)", fontdict = font_1)
plt.xlabel("Year", fontdict = font_2)
plt.ylabel("Long-term Average = 100", fontdict = font_2)

# Highlights
plt.axvspan(date2num(datetime(2020,1,1)), date2num(datetime(2023,1,1)), 
           label="2020 COVID-19 Pandemic", color="green", alpha=0.1)
plt.axvspan(date2num(datetime(2007,1,1)), date2num(datetime(2009,1,1)), 
           label="2008 Global Financial Crisis", color="red", alpha=0.1)
plt.axvspan(date2num(datetime(2012,1,1)), date2num(datetime(2015,1,1)), 
           label="2012–2014 European Debt Crisis", color="orange", alpha=0.1)
plt.axvspan(date2num(datetime(1987,1,1)), date2num(datetime(1990,1,1)), 
           label="1987 Stock Market Crash", color="blue", alpha=0.1)
plt.axvspan(date2num(datetime(1973,1,1)), date2num(datetime(1975,1,1)), 
           label="1973–1974 Stock Market Crash", color="purple", alpha=0.1)
plt.legend()

# Aesthetics
matplotlib.pyplot.grid(visible=True, which='both', axis='both', color='blue', alpha=0.1, linestyle='--', linewidth=1)

plt.gca().spines['top'].set_visible(False)
plt.gca().spines['right'].set_visible(False)
plt.tight_layout()

# Save and show
plt.savefig("/Users/minoperic/Data Analytics/Data Investigations/global-economic-indicators/Images/cli_france.png", dpi=300)
plt.show()

# %%
# Plotting – CLI (Great Britain)

# Font families
font_1 = {'family':'helvetica','color':'black','size':16}
font_2 = {'family':'helvetica','color':'black','size':12}

# Plot
plt.figure(figsize=(15,5))
plt.plot(gbr_cli_df['TIME'], gbr_cli_df['VALUE'], color='blue', linewidth=3)

# Labels
plt.title("Consumer Leading Indicator (CLI) – Great Britain, amplitude adjusted (1970–2022)", fontdict = font_1)
plt.xlabel("Year", fontdict = font_2)
plt.ylabel("Long-term Average = 100", fontdict = font_2)

# Highlights
plt.axvspan(date2num(datetime(2020,1,1)), date2num(datetime(2023,1,1)), 
           label="2020 COVID-19 Pandemic", color="green", alpha=0.1)
plt.axvspan(date2num(datetime(2007,1,1)), date2num(datetime(2009,1,1)), 
           label="2008 Global Financial Crisis", color="red", alpha=0.1)
plt.axvspan(date2num(datetime(2012,1,1)), date2num(datetime(2015,1,1)), 
           label="2012–2014 European Debt Crisis", color="orange", alpha=0.1)
plt.axvspan(date2num(datetime(1987,1,1)), date2num(datetime(1990,1,1)), 
           label="1987 Stock Market Crash", color="blue", alpha=0.1)
plt.axvspan(date2num(datetime(1973,1,1)), date2num(datetime(1975,1,1)), 
           label="1973–1974 Stock Market Crash", color="purple", alpha=0.1)
plt.legend()

# Aesthetics
matplotlib.pyplot.grid(visible=True, which='both', axis='both', color='blue', alpha=0.1, linestyle='--', linewidth=1)

plt.gca().spines['top'].set_visible(False)
plt.gca().spines['right'].set_visible(False)
plt.tight_layout()

# Save and show
plt.savefig("/Users/minoperic/Data Analytics/Data Investigations/global-economic-indicators/Images/cli_great_britain.png", dpi=300)
plt.show()

# %%
# Plotting – CLI (Italy)

# Font families
font_1 = {'family':'helvetica','color':'black','size':16}
font_2 = {'family':'helvetica','color':'black','size':12}

# Plot
plt.figure(figsize=(15,5))
plt.plot(ita_cli_df['TIME'], ita_cli_df['VALUE'], color='blue', linewidth=3)

# Labels
plt.title("Consumer Leading Indicator (CLI) – Italy, amplitude adjusted (1970–2022)", fontdict = font_1)
plt.xlabel("Year", fontdict = font_2)
plt.ylabel("Long-term Average = 100", fontdict = font_2)

# Highlights
plt.axvspan(date2num(datetime(2020,1,1)), date2num(datetime(2023,1,1)), 
           label="2020 COVID-19 Pandemic", color="green", alpha=0.1)
plt.axvspan(date2num(datetime(2007,1,1)), date2num(datetime(2009,1,1)), 
           label="2008 Global Financial Crisis", color="red", alpha=0.1)
plt.axvspan(date2num(datetime(2012,1,1)), date2num(datetime(2015,1,1)), 
           label="2012–2014 European Debt Crisis", color="orange", alpha=0.1)
plt.axvspan(date2num(datetime(1987,1,1)), date2num(datetime(1990,1,1)), 
           label="1987 Stock Market Crash", color="blue", alpha=0.1)
plt.axvspan(date2num(datetime(1973,1,1)), date2num(datetime(1975,1,1)), 
           label="1973–1974 Stock Market Crash", color="purple", alpha=0.1)
plt.legend()

# Aesthetics
matplotlib.pyplot.grid(visible=True, which='both', axis='both', color='blue', alpha=0.1, linestyle='--', linewidth=1)

plt.gca().spines['top'].set_visible(False)
plt.gca().spines['right'].set_visible(False)
plt.tight_layout()

# Save and show
plt.savefig("/Users/minoperic/Data Analytics/Data Investigations/global-economic-indicators/Images/cli_italy.png", dpi=300)
plt.show()

# %%
# Plotting – CLI (Japan)

# Font families
font_1 = {'family':'helvetica','color':'black','size':16}
font_2 = {'family':'helvetica','color':'black','size':12}

# Plot
plt.figure(figsize=(15,5))
plt.plot(jpn_cli_df['TIME'], jpn_cli_df['VALUE'], color='blue', linewidth=3)

# Labels
plt.title("Consumer Leading Indicator (CLI) – Japan, amplitude adjusted (1970–2022)", fontdict = font_1)
plt.xlabel("Year", fontdict = font_2)
plt.ylabel("Long-term Average = 100", fontdict = font_2)

# Highlights
plt.axvspan(date2num(datetime(2020,1,1)), date2num(datetime(2023,1,1)), 
           label="2020 COVID-19 Pandemic", color="green", alpha=0.1)
plt.axvspan(date2num(datetime(2007,1,1)), date2num(datetime(2009,1,1)), 
           label="2008 Global Financial Crisis", color="red", alpha=0.1)
plt.axvspan(date2num(datetime(2012,1,1)), date2num(datetime(2015,1,1)), 
           label="2012–2014 European Debt Crisis", color="orange", alpha=0.1)
plt.axvspan(date2num(datetime(1987,1,1)), date2num(datetime(1990,1,1)), 
           label="1987 Stock Market Crash", color="blue", alpha=0.1)
plt.axvspan(date2num(datetime(1973,1,1)), date2num(datetime(1975,1,1)), 
           label="1973–1974 Stock Market Crash", color="purple", alpha=0.1)
plt.legend()

# Aesthetics
matplotlib.pyplot.grid(visible=True, which='both', axis='both', color='blue', alpha=0.1, linestyle='--', linewidth=1)

plt.gca().spines['top'].set_visible(False)
plt.gca().spines['right'].set_visible(False)
plt.tight_layout()

# Save and show
plt.savefig("/Users/minoperic/Data Analytics/Data Investigations/global-economic-indicators/Images/cli_japan.png", dpi=300)
plt.show()

# %%
# Plotting – CLI (OECD)

# Font families
font_1 = {'family':'helvetica','color':'black','size':16}
font_2 = {'family':'helvetica','color':'black','size':12}

# Plot
plt.figure(figsize=(15,5))
plt.plot(oecd_cli_df['TIME'], oecd_cli_df['VALUE'], color='blue', linewidth=3)

# Labels
plt.title("Consumer Leading Indicator (CLI) – OECD, amplitude adjusted (1970–2022)", fontdict = font_1)
plt.xlabel("Year", fontdict = font_2)
plt.ylabel("Long-term Average = 100", fontdict = font_2)

# Highlights
plt.axvspan(date2num(datetime(2020,1,1)), date2num(datetime(2023,1,1)), 
           label="2020 COVID-19 Pandemic", color="green", alpha=0.1)
plt.axvspan(date2num(datetime(2007,1,1)), date2num(datetime(2009,1,1)), 
           label="2008 Global Financial Crisis", color="red", alpha=0.1)
plt.axvspan(date2num(datetime(2012,1,1)), date2num(datetime(2015,1,1)), 
           label="2012–2014 European Debt Crisis", color="orange", alpha=0.1)
plt.axvspan(date2num(datetime(1987,1,1)), date2num(datetime(1990,1,1)), 
           label="1987 Stock Market Crash", color="blue", alpha=0.1)
plt.axvspan(date2num(datetime(1973,1,1)), date2num(datetime(1975,1,1)), 
           label="1973–1974 Stock Market Crash", color="purple", alpha=0.1)
plt.legend()

# Aesthetics
matplotlib.pyplot.grid(visible=True, which='both', axis='both', color='blue', alpha=0.1, linestyle='--', linewidth=1)

plt.gca().spines['top'].set_visible(False)
plt.gca().spines['right'].set_visible(False)
plt.tight_layout()

# Save and show
plt.savefig("/Users/minoperic/Data Analytics/Data Investigations/global-economic-indicators/Images/cli_oecd.png", dpi=300)
plt.show()

# %%
# Plotting – CLI (Russia)

# Font families
font_1 = {'family':'helvetica','color':'black','size':16}
font_2 = {'family':'helvetica','color':'black','size':12}

# Plot
plt.figure(figsize=(15,5))
plt.plot(rus_cli_df['TIME'], rus_cli_df['VALUE'], color='blue', linewidth=3)

# Labels
plt.title("Consumer Leading Indicator (CLI) – Russia, amplitude adjusted (1970–2022)", fontdict = font_1)
plt.xlabel("Year", fontdict = font_2)
plt.ylabel("Long-term Average = 100", fontdict = font_2)

# Highlights
plt.axvspan(date2num(datetime(2020,1,1)), date2num(datetime(2023,1,1)), 
           label="2020 COVID-19 Pandemic", color="green", alpha=0.1)
plt.axvspan(date2num(datetime(2007,1,1)), date2num(datetime(2009,1,1)), 
           label="2008 Global Financial Crisis", color="red", alpha=0.1)
plt.axvspan(date2num(datetime(2012,1,1)), date2num(datetime(2015,1,1)), 
           label="2012–2014 European Debt Crisis", color="orange", alpha=0.1)
# plt.axvspan(date2num(datetime(1987,1,1)), date2num(datetime(1990,1,1)), 
#            label="1987 Stock Market Crash", color="blue", alpha=0.1)
# plt.axvspan(date2num(datetime(1973,1,1)), date2num(datetime(1975,1,1)), 
#            label="1973–1974 Stock Market Crash", color="purple", alpha=0.1)
plt.legend()

# Aesthetics
matplotlib.pyplot.grid(visible=True, which='both', axis='both', color='blue', alpha=0.1, linestyle='--', linewidth=1)

plt.gca().spines['top'].set_visible(False)
plt.gca().spines['right'].set_visible(False)
plt.tight_layout()

# Save and show
plt.savefig("/Users/minoperic/Data Analytics/Data Investigations/global-economic-indicators/Images/cli_russia.png", dpi=300)
plt.show()

# %%
# Plotting – CLI (USA)

# Font families
font_1 = {'family':'helvetica','color':'black','size':16}
font_2 = {'family':'helvetica','color':'black','size':12}

# Plot
plt.figure(figsize=(15,5))
plt.plot(usa_cli_df['TIME'], usa_cli_df['VALUE'], color='blue', linewidth=3)

# Labels
plt.title("Consumer Leading Indicator (CLI) – USA, amplitude adjusted (1970–2022)", fontdict = font_1)
plt.xlabel("Year", fontdict = font_2)
plt.ylabel("Long-term Average = 100", fontdict = font_2)

# Highlights
plt.axvspan(date2num(datetime(2020,1,1)), date2num(datetime(2023,1,1)), 
           label="2020 COVID-19 Pandemic", color="green", alpha=0.1)
plt.axvspan(date2num(datetime(2007,1,1)), date2num(datetime(2009,1,1)), 
           label="2008 Global Financial Crisis", color="red", alpha=0.1)
plt.axvspan(date2num(datetime(2012,1,1)), date2num(datetime(2015,1,1)), 
           label="2012–2014 European Debt Crisis", color="orange", alpha=0.1)
plt.axvspan(date2num(datetime(1987,1,1)), date2num(datetime(1990,1,1)), 
           label="1987 Stock Market Crash", color="blue", alpha=0.1)
plt.axvspan(date2num(datetime(1973,1,1)), date2num(datetime(1975,1,1)), 
           label="1973–1974 Stock Market Crash", color="purple", alpha=0.1)
plt.legend()

# Aesthetics
matplotlib.pyplot.grid(visible=True, which='both', axis='both', color='blue', alpha=0.1, linestyle='--', linewidth=1)

plt.gca().spines['top'].set_visible(False)
plt.gca().spines['right'].set_visible(False)
plt.tight_layout()

# Save and show
plt.savefig("/Users/minoperic/Data Analytics/Data Investigations/global-economic-indicators/Images/cli_usa.png", dpi=300)
plt.show()

# %%
## Exchange Rates

# %%
# Create new DataFrames based on locations (countries)

#
    
aus_exchange_rates_df = exchange_rates_df[exchange_rates_df.LOCATION == 'AUS'] #Australia
can_exchange_rates_df = exchange_rates_df[exchange_rates_df.LOCATION == 'CAN'] #Canada
deu_exchange_rates_df = exchange_rates_df[exchange_rates_df.LOCATION == 'DEU'] #Germany
fra_exchange_rates_df = exchange_rates_df[exchange_rates_df.LOCATION == 'FRA'] #Australia
gbr_exchange_rates_df = exchange_rates_df[exchange_rates_df.LOCATION == 'GBR'] #Great Britain
ita_exchange_rates_df = exchange_rates_df[exchange_rates_df.LOCATION == 'ITA'] #Italy
jpn_exchange_rates_df = exchange_rates_df[exchange_rates_df.LOCATION == 'JPN'] #Japan
rus_exchange_rates_df = exchange_rates_df[exchange_rates_df.LOCATION == 'RUS'] #Russia
usa_exchange_rates_df = exchange_rates_df[exchange_rates_df.LOCATION == 'USA'] #USA

exchange_rates_df
# Out:
#     LOCATION       TIME     VALUE
# 0        AUS 1970-01-01  0.892857
# 1        AUS 1971-01-01  0.882670
# 2        AUS 1972-01-01  0.838698
# 3        AUS 1973-01-01  0.704114
# 4        AUS 1974-01-01  0.696666
# ..       ...        ...       ...
# 440      USA 2017-01-01  1.000000
# 441      USA 2018-01-01  1.000000
# 442      USA 2019-01-01  1.000000
# 443      USA 2020-01-01  1.000000
# 444      USA 2021-01-01  1.000000
#
# [445 rows x 3 columns]

# %%
# Plotting – Exchange Rates (Australia)

# Font families
font_1 = {'family':'helvetica','color':'black','size':16}
font_2 = {'family':'helvetica','color':'black','size':12}

# Plot
plt.figure(figsize=(15,5))
plt.plot(aus_exchange_rates_df['TIME'], aus_exchange_rates_df['VALUE'], color='blue', linewidth=3)

# Labels
plt.title("Exchange Rates – Australia, (1970–2021)", fontdict = font_1)
plt.xlabel("Year", fontdict = font_2)
plt.ylabel("National currency units/USD", fontdict = font_2)

# Highlights
plt.axvspan(date2num(datetime(2020,1,1)), date2num(datetime(2023,1,1)), 
           label="2020 COVID-19 Pandemic", color="green", alpha=0.1)
plt.axvspan(date2num(datetime(2007,1,1)), date2num(datetime(2009,1,1)), 
           label="2008 Global Financial Crisis", color="red", alpha=0.1)
plt.axvspan(date2num(datetime(2012,1,1)), date2num(datetime(2015,1,1)), 
           label="2012–2014 European Debt Crisis", color="orange", alpha=0.1)
plt.axvspan(date2num(datetime(1987,1,1)), date2num(datetime(1990,1,1)), 
           label="1987 Stock Market Crash", color="blue", alpha=0.1)
plt.axvspan(date2num(datetime(1973,1,1)), date2num(datetime(1975,1,1)), 
           label="1973–1974 Stock Market Crash", color="purple", alpha=0.1)
plt.legend()

# Aesthetics
matplotlib.pyplot.grid(visible=True, which='both', axis='both', color='blue', alpha=0.1, linestyle='--', linewidth=1)

plt.gca().spines['top'].set_visible(False)
plt.gca().spines['right'].set_visible(False)
plt.tight_layout()

# Save and show
plt.savefig("/Users/minoperic/Data Analytics/Data Investigations/global-economic-indicators/Images/exchange_rates_australia.png", dpi=300)
plt.show()

# %%
# Plotting – Exchange Rates (Canada)

# Font families
font_1 = {'family':'helvetica','color':'black','size':16}
font_2 = {'family':'helvetica','color':'black','size':12}

# Plot
plt.figure(figsize=(15,5))
plt.plot(can_exchange_rates_df['TIME'], can_exchange_rates_df['VALUE'], color='blue', linewidth=3)

# Labels
plt.title("Exchange Rates – Canada, (1970–2021)", fontdict = font_1)
plt.xlabel("Year", fontdict = font_2)
plt.ylabel("National currency units/USD", fontdict = font_2)

# Highlights
plt.axvspan(date2num(datetime(2020,1,1)), date2num(datetime(2023,1,1)), 
           label="2020 COVID-19 Pandemic", color="green", alpha=0.1)
plt.axvspan(date2num(datetime(2007,1,1)), date2num(datetime(2009,1,1)), 
           label="2008 Global Financial Crisis", color="red", alpha=0.1)
plt.axvspan(date2num(datetime(2012,1,1)), date2num(datetime(2015,1,1)), 
           label="2012–2014 European Debt Crisis", color="orange", alpha=0.1)
plt.axvspan(date2num(datetime(1987,1,1)), date2num(datetime(1990,1,1)), 
           label="1987 Stock Market Crash", color="blue", alpha=0.1)
plt.axvspan(date2num(datetime(1973,1,1)), date2num(datetime(1975,1,1)), 
           label="1973–1974 Stock Market Crash", color="purple", alpha=0.1)
plt.legend()

# Aesthetics
matplotlib.pyplot.grid(visible=True, which='both', axis='both', color='blue', alpha=0.1, linestyle='--', linewidth=1)

plt.gca().spines['top'].set_visible(False)
plt.gca().spines['right'].set_visible(False)
plt.tight_layout()

# Save and show
plt.savefig("/Users/minoperic/Data Analytics/Data Investigations/global-economic-indicators/Images/exchange_rates_canada.png", dpi=300)
plt.show()

# %%
# Plotting – Exchange Rates (Germany)

# Font families
font_1 = {'family':'helvetica','color':'black','size':16}
font_2 = {'family':'helvetica','color':'black','size':12}

# Plot
plt.figure(figsize=(15,5))
plt.plot(deu_exchange_rates_df['TIME'], deu_exchange_rates_df['VALUE'], color='blue', linewidth=3)

# Labels
plt.title("Exchange Rates – Germany, (1970–2021)", fontdict = font_1)
plt.xlabel("Year", fontdict = font_2)
plt.ylabel("National currency units/USD", fontdict = font_2)

# Highlights
plt.axvspan(date2num(datetime(2020,1,1)), date2num(datetime(2023,1,1)), 
           label="2020 COVID-19 Pandemic", color="green", alpha=0.1)
plt.axvspan(date2num(datetime(2007,1,1)), date2num(datetime(2009,1,1)), 
           label="2008 Global Financial Crisis", color="red", alpha=0.1)
plt.axvspan(date2num(datetime(2012,1,1)), date2num(datetime(2015,1,1)), 
           label="2012–2014 European Debt Crisis", color="orange", alpha=0.1)
plt.axvspan(date2num(datetime(1987,1,1)), date2num(datetime(1990,1,1)), 
           label="1987 Stock Market Crash", color="blue", alpha=0.1)
plt.axvspan(date2num(datetime(1973,1,1)), date2num(datetime(1975,1,1)), 
           label="1973–1974 Stock Market Crash", color="purple", alpha=0.1)
plt.legend()

# Aesthetics
matplotlib.pyplot.grid(visible=True, which='both', axis='both', color='blue', alpha=0.1, linestyle='--', linewidth=1)

plt.gca().spines['top'].set_visible(False)
plt.gca().spines['right'].set_visible(False)
plt.tight_layout()

# Save and show
plt.savefig("/Users/minoperic/Data Analytics/Data Investigations/global-economic-indicators/Images/exchange_rates_Germany.png", dpi=300)
plt.show()

# %%
# Plotting – Exchange Rates (France)

# Font families
font_1 = {'family':'helvetica','color':'black','size':16}
font_2 = {'family':'helvetica','color':'black','size':12}

# Plot
plt.figure(figsize=(15,5))
plt.plot(fra_exchange_rates_df['TIME'], fra_exchange_rates_df['VALUE'], color='blue', linewidth=3)

# Labels
plt.title("Exchange Rates – France, (1970–2021)", fontdict = font_1)
plt.xlabel("Year", fontdict = font_2)
plt.ylabel("National currency units/USD", fontdict = font_2)

# Highlights
plt.axvspan(date2num(datetime(2020,1,1)), date2num(datetime(2023,1,1)), 
           label="2020 COVID-19 Pandemic", color="green", alpha=0.1)
plt.axvspan(date2num(datetime(2007,1,1)), date2num(datetime(2009,1,1)), 
           label="2008 Global Financial Crisis", color="red", alpha=0.1)
plt.axvspan(date2num(datetime(2012,1,1)), date2num(datetime(2015,1,1)), 
           label="2012–2014 European Debt Crisis", color="orange", alpha=0.1)
plt.axvspan(date2num(datetime(1987,1,1)), date2num(datetime(1990,1,1)), 
           label="1987 Stock Market Crash", color="blue", alpha=0.1)
plt.axvspan(date2num(datetime(1973,1,1)), date2num(datetime(1975,1,1)), 
           label="1973–1974 Stock Market Crash", color="purple", alpha=0.1)
plt.legend()

# Aesthetics
matplotlib.pyplot.grid(visible=True, which='both', axis='both', color='blue', alpha=0.1, linestyle='--', linewidth=1)

plt.gca().spines['top'].set_visible(False)
plt.gca().spines['right'].set_visible(False)
plt.tight_layout()

# Save and show
plt.savefig("/Users/minoperic/Data Analytics/Data Investigations/global-economic-indicators/Images/exchange_rates_france.png", dpi=300)
plt.show()

# %%
# Plotting – Exchange Rates (Italy)

# Font families
font_1 = {'family':'helvetica','color':'black','size':16}
font_2 = {'family':'helvetica','color':'black','size':12}

# Plot
plt.figure(figsize=(15,5))
plt.plot(ita_exchange_rates_df['TIME'], ita_exchange_rates_df['VALUE'], color='blue', linewidth=3)

# Labels
plt.title("Exchange Rates – Italy, (1970–2021)", fontdict = font_1)
plt.xlabel("Year", fontdict = font_2)
plt.ylabel("National currency units/USD", fontdict = font_2)

# Highlights
plt.axvspan(date2num(datetime(2020,1,1)), date2num(datetime(2023,1,1)), 
           label="2020 COVID-19 Pandemic", color="green", alpha=0.1)
plt.axvspan(date2num(datetime(2007,1,1)), date2num(datetime(2009,1,1)), 
           label="2008 Global Financial Crisis", color="red", alpha=0.1)
plt.axvspan(date2num(datetime(2012,1,1)), date2num(datetime(2015,1,1)), 
           label="2012–2014 European Debt Crisis", color="orange", alpha=0.1)
plt.axvspan(date2num(datetime(1987,1,1)), date2num(datetime(1990,1,1)), 
           label="1987 Stock Market Crash", color="blue", alpha=0.1)
plt.axvspan(date2num(datetime(1973,1,1)), date2num(datetime(1975,1,1)), 
           label="1973–1974 Stock Market Crash", color="purple", alpha=0.1)
plt.legend()

# Aesthetics
matplotlib.pyplot.grid(visible=True, which='both', axis='both', color='blue', alpha=0.1, linestyle='--', linewidth=1)

plt.gca().spines['top'].set_visible(False)
plt.gca().spines['right'].set_visible(False)
plt.tight_layout()

# Save and show
plt.savefig("/Users/minoperic/Data Analytics/Data Investigations/global-economic-indicators/Images/exchange_rates_italy.png", dpi=300)
plt.show()

# %%
# Plotting – Exchange Rates (Japan)

# Font families
font_1 = {'family':'helvetica','color':'black','size':16}
font_2 = {'family':'helvetica','color':'black','size':12}

# Plot
plt.figure(figsize=(15,5))
plt.plot(jpn_exchange_rates_df['TIME'], jpn_exchange_rates_df['VALUE'], color='blue', linewidth=3)

# Labels
plt.title("Exchange Rates – Japan, (1970–2021)", fontdict = font_1)
plt.xlabel("Year", fontdict = font_2)
plt.ylabel("National currency units/USD", fontdict = font_2)

# Highlights
plt.axvspan(date2num(datetime(2020,1,1)), date2num(datetime(2023,1,1)), 
           label="2020 COVID-19 Pandemic", color="green", alpha=0.1)
plt.axvspan(date2num(datetime(2007,1,1)), date2num(datetime(2009,1,1)), 
           label="2008 Global Financial Crisis", color="red", alpha=0.1)
plt.axvspan(date2num(datetime(2012,1,1)), date2num(datetime(2015,1,1)), 
           label="2012–2014 European Debt Crisis", color="orange", alpha=0.1)
plt.axvspan(date2num(datetime(1987,1,1)), date2num(datetime(1990,1,1)), 
           label="1987 Stock Market Crash", color="blue", alpha=0.1)
plt.axvspan(date2num(datetime(1973,1,1)), date2num(datetime(1975,1,1)), 
           label="1973–1974 Stock Market Crash", color="purple", alpha=0.1)
plt.legend()

# Aesthetics
matplotlib.pyplot.grid(visible=True, which='both', axis='both', color='blue', alpha=0.1, linestyle='--', linewidth=1)

plt.gca().spines['top'].set_visible(False)
plt.gca().spines['right'].set_visible(False)
plt.tight_layout()

# Save and show
plt.savefig("/Users/minoperic/Data Analytics/Data Investigations/global-economic-indicators/Images/exchange_rates_japan.png", dpi=300)
plt.show()

# %%
# Plotting – Exchange Rates (Russia)

# Font families
font_1 = {'family':'helvetica','color':'black','size':16}
font_2 = {'family':'helvetica','color':'black','size':12}

# Plot
plt.figure(figsize=(15,5))
plt.plot(rus_exchange_rates_df['TIME'], rus_exchange_rates_df['VALUE'], color='blue', linewidth=3)

# Labels
plt.title("Exchange Rates – Russia, (1970–2021)", fontdict = font_1)
plt.xlabel("Year", fontdict = font_2)
plt.ylabel("National currency units/USD", fontdict = font_2)

# Highlights
plt.axvspan(date2num(datetime(2020,1,1)), date2num(datetime(2023,1,1)), 
           label="2020 COVID-19 Pandemic", color="green", alpha=0.1)
plt.axvspan(date2num(datetime(2007,1,1)), date2num(datetime(2009,1,1)), 
           label="2008 Global Financial Crisis", color="red", alpha=0.1)
plt.axvspan(date2num(datetime(2012,1,1)), date2num(datetime(2015,1,1)), 
           label="2012–2014 European Debt Crisis", color="orange", alpha=0.1)
# plt.axvspan(date2num(datetime(1987,1,1)), date2num(datetime(1990,1,1)), 
#            label="1987 Stock Market Crash", color="blue", alpha=0.1)
# plt.axvspan(date2num(datetime(1973,1,1)), date2num(datetime(1975,1,1)), 
#            label="1973–1974 Stock Market Crash", color="purple", alpha=0.1)
plt.legend()

# Aesthetics
matplotlib.pyplot.grid(visible=True, which='both', axis='both', color='blue', alpha=0.1, linestyle='--', linewidth=1)

plt.gca().spines['top'].set_visible(False)
plt.gca().spines['right'].set_visible(False)
plt.tight_layout()

# Save and show
plt.savefig("/Users/minoperic/Data Analytics/Data Investigations/global-economic-indicators/Images/exchange_rates_russia.png", dpi=300)
plt.show()

# %%
## Financial corporate debt to equity ratio

# %%
# Create new DataFrames based on locations (countries)
    
#fcdter_df['LOCATION'].unique()
    
aus_fcdter_df = fcdter_df[fcdter_df.LOCATION == 'AUS'] #Australia
can_fcdter_df = fcdter_df[fcdter_df.LOCATION == 'CAN'] #Canada
deu_fcdter_df = fcdter_df[fcdter_df.LOCATION == 'DEU'] #Germany
fra_fcdter_df = fcdter_df[fcdter_df.LOCATION == 'FRA'] #France
gbr_fcdter_df = fcdter_df[fcdter_df.LOCATION == 'GBR'] #Great Britain
ita_fcdter_df = fcdter_df[fcdter_df.LOCATION == 'ITA'] #Italy
jpn_fcdter_df = fcdter_df[fcdter_df.LOCATION == 'JPN'] #Japan
rus_fcdter_df = fcdter_df[fcdter_df.LOCATION == 'RUS'] #Russia

fcdter_df
# Out:
#     LOCATION       TIME     VALUE
# 0        AUS 1995-01-01  8.049250
# 1        AUS 1996-01-01  7.624223
# 2        AUS 1997-01-01  6.543419
# 3        AUS 1998-01-01  5.789336
# 4        AUS 1999-01-01  6.194106
# ..       ...        ...       ...
# 213      USA 2016-01-01  2.275780
# 214      USA 2017-01-01  2.094415
# 215      USA 2018-01-01  2.242058
# 216      USA 2019-01-01  1.979779
# 217      USA 2020-01-01  2.022087
#
# [218 rows x 3 columns]

# %%
# Plotting – Financial Corporate Debt To Equity (Australia)

# Font families
font_1 = {'family':'helvetica','color':'black','size':16}
font_2 = {'family':'helvetica','color':'black','size':12}

# Plot
plt.figure(figsize=(15,5))
plt.plot(aus_fcdter_df['TIME'], aus_fcdter_df['VALUE'], color='blue', linewidth=3)

# Labels
plt.title("Financial Corporations Debt-to-Equity – Australia, (1995–2020)", fontdict = font_1)
plt.xlabel("Year", fontdict = font_2)
plt.ylabel("Debt-to-equity ratio", fontdict = font_2)

# Highlights
plt.axvspan(date2num(datetime(2007,1,1)), date2num(datetime(2009,1,1)), 
           label="2008 Global Financial Crisis", color="red", alpha=0.1)
plt.axvspan(date2num(datetime(2012,1,1)), date2num(datetime(2015,1,1)), 
           label="2012–2014 European Debt Crisis", color="orange", alpha=0.1)
plt.legend()

# Aesthetics
matplotlib.pyplot.grid(visible=True, which='both', axis='both', color='blue', alpha=0.1, linestyle='--', linewidth=1)

plt.gca().spines['top'].set_visible(False)
plt.gca().spines['right'].set_visible(False)
plt.tight_layout()

# Save and show
plt.savefig("/Users/minoperic/Data Analytics/Data Investigations/global-economic-indicators/Images/fcdter_australia.png", dpi=300)
plt.show()

# %%
# Plotting – Financial Corporate Debt To Equity (Canada)

# Font families
font_1 = {'family':'helvetica','color':'black','size':16}
font_2 = {'family':'helvetica','color':'black','size':12}

# Plot
plt.figure(figsize=(15,5))
plt.plot(can_fcdter_df['TIME'], can_fcdter_df['VALUE'], color='blue', linewidth=3)

# Labels
plt.title("Financial Corporations Debt-to-Equity – Canada, (1995–2020)", fontdict = font_1)
plt.xlabel("Year", fontdict = font_2)
plt.ylabel("Debt-to-equity ratio", fontdict = font_2)

# Highlights
plt.axvspan(date2num(datetime(2007,1,1)), date2num(datetime(2009,1,1)), 
           label="2008 Global Financial Crisis", color="red", alpha=0.1)
plt.axvspan(date2num(datetime(2012,1,1)), date2num(datetime(2015,1,1)), 
           label="2012–2014 European Debt Crisis", color="orange", alpha=0.1)
plt.legend()

# Aesthetics
matplotlib.pyplot.grid(visible=True, which='both', axis='both', color='blue', alpha=0.1, linestyle='--', linewidth=1)

plt.gca().spines['top'].set_visible(False)
plt.gca().spines['right'].set_visible(False)
plt.tight_layout()

# Save and show
plt.savefig("/Users/minoperic/Data Analytics/Data Investigations/global-economic-indicators/Images/fcdter_canada.png", dpi=300)
plt.show()

# %%
# Plotting – Financial Corporate Debt To Equity (Germany)

# Font families
font_1 = {'family':'helvetica','color':'black','size':16}
font_2 = {'family':'helvetica','color':'black','size':12}

# Plot
plt.figure(figsize=(15,5))
plt.plot(deu_fcdter_df['TIME'], deu_fcdter_df['VALUE'], color='blue', linewidth=3)

# Labels
plt.title("Financial Corporations Debt-to-Equity – Germany, (1995–2020)", fontdict = font_1)
plt.xlabel("Year", fontdict = font_2)
plt.ylabel("Debt-to-equity ratio", fontdict = font_2)

# Highlights
plt.axvspan(date2num(datetime(2007,1,1)), date2num(datetime(2009,1,1)), 
           label="2008 Global Financial Crisis", color="red", alpha=0.1)
plt.axvspan(date2num(datetime(2012,1,1)), date2num(datetime(2015,1,1)), 
           label="2012–2014 European Debt Crisis", color="orange", alpha=0.1)
plt.legend()

# Aesthetics
matplotlib.pyplot.grid(visible=True, which='both', axis='both', color='blue', alpha=0.1, linestyle='--', linewidth=1)

plt.gca().spines['top'].set_visible(False)
plt.gca().spines['right'].set_visible(False)
plt.tight_layout()

# Save and show
plt.savefig("/Users/minoperic/Data Analytics/Data Investigations/global-economic-indicators/Images/fcdter_germany.png", dpi=300)
plt.show()

# %%
# Plotting – Financial Corporate Debt To Equity (France)

# Font families
font_1 = {'family':'helvetica','color':'black','size':16}
font_2 = {'family':'helvetica','color':'black','size':12}

# Plot
plt.figure(figsize=(15,5))
plt.plot(fra_fcdter_df['TIME'], fra_fcdter_df['VALUE'], color='blue', linewidth=3)

# Labels
plt.title("Financial Corporations Debt-to-Equity – Canada, (1995–2020)", fontdict = font_1)
plt.xlabel("Year", fontdict = font_2)
plt.ylabel("Debt-to-equity ratio", fontdict = font_2)

# Highlights
plt.axvspan(date2num(datetime(2007,1,1)), date2num(datetime(2009,1,1)), 
           label="2008 Global Financial Crisis", color="red", alpha=0.1)
plt.axvspan(date2num(datetime(2012,1,1)), date2num(datetime(2015,1,1)), 
           label="2012–2014 European Debt Crisis", color="orange", alpha=0.1)
plt.legend()

# Aesthetics
matplotlib.pyplot.grid(visible=True, which='both', axis='both', color='blue', alpha=0.1, linestyle='--', linewidth=1)

plt.gca().spines['top'].set_visible(False)
plt.gca().spines['right'].set_visible(False)
plt.tight_layout()

# Save and show
plt.savefig("/Users/minoperic/Data Analytics/Data Investigations/global-economic-indicators/Images/fcdter_canada.png", dpi=300)
plt.show()
